# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return x ** 2 * np.sin(x)

# %%
def f_dash(x):
    return 2 * x * np.sin(x) + x ** 2 * np.cos(x)

# %%
def draw_plot(f, x_begin, x_end):
    x_array = np.linspace(x_begin, x_end, 1000)
    plt.plot(x_array, f(x_array))

# %%
draw_plot(f, x_begin=1, x_end=8)

# %%
def gradient_descent_step(f_dash, x, alpha=0.001):
    f_dash_x = f_dash(x)
    delta_x = alpha * f_dash_x
    x_new = x - delta_x

    return x_new

# %%
gradient_descent_step(f_dash, 2, alpha=0.1)
# Out:
# 1.8027397638885843

# %%
from IPython.display import clear_output

def draw_plot(f, x_begin, x_end, xs, ys):


    x_ = np.linspace(x_begin, x_end, 1000)
    plt.plot(x_, f(x_))


    plt.scatter(xs, ys)
    plt.annotate(' x = {}, y = {}'.format(round(xs[-1], 1), round(ys[-1], 1)), (xs[-1],ys[-1]))


    plt.title("f(x)")

    plt.show()

    clear_output(wait=True)

# %%
def gradient_descent(f, f_dash, x, alpha=0.001, epsilon=0.01):


    y = f(x)
    xs = [x]
    ys = [y]

    step_count = 0
    while True:

        step_count += 1
        x = gradient_descent_step(f_dash, x, alpha)

        y = f(x)

        previous_y = ys[-1]

        delta_y = np.abs(y - previous_y)


        xs.append(x)
        ys.append(y)


        draw_plot(f, 1, 8, xs, ys)
        
        if delta_y < epsilon and step_count >= 1000:
            break

# %%
alpha = 0.005
epsilon = 0.001

# %%
x = 2.5

# %%
gradient_descent(f, f_dash, x, alpha, epsilon)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-9a16b9b809d6> in <module>
# ----> 1 gradient_descent(f, f_dash, x, alpha, epsilon)
#
# <ipython-input-28-4cd051a7ce8a> in gradient_descent(f, f_dash, x, alpha, epsilon)
#      23
#      24
# ---> 25         draw_plot(f, 1, 8, xs, ys)
#      26         if delta_y < epsilon and step_count >= 1000:
#      27             break
#
# <ipython-input-12-61901300084b> in draw_plot(f, x_begin, x_end, xs, ys)
#      14     plt.title("f(x)")
#      15
# ---> 16     plt.show()
#      17
#      18     clear_output(wait=True)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2100                         self.figure.draw(renderer)
#    2101                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
# -> 2102                     bbox_inches = self.figure.get_tightbbox(renderer,
#    2103                             bbox_extra_artists=bbox_artists)
#    2104                     pad = kwargs.pop("pad_inches", None)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2383
#    2384         for a in artists:
# -> 2385             bbox = a.get_tightbbox(renderer)
#    2386             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2387                 bb.append(bbox)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4321
#    4322         if self.axison:
# -> 4323             bb_xaxis = self.xaxis.get_tightbbox(renderer)
#    4324             if bb_xaxis:
#    4325                 bb.append(bb_xaxis)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1186         ticks_to_draw = self._update_ticks()
#    1187
# -> 1188         self._update_label_position(renderer)
#    1189
#    1190         # go back to just this axis's tick labels
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2019         # get bounding boxes for this axis and any siblings
#    2020         # that have been set by `fig.align_xlabels()`
# -> 2021         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2022
#    2023         x, y = self.label.get_position()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2003         # if we want to align labels from other axes:
#    2004         for nn, axx in enumerate(grp.get_siblings(self.axes)):
# -> 2005             ticks_to_draw = axx.xaxis._update_ticks()
#    2006             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2007             bboxes.extend(tlb)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1106         self.major.formatter.set_locs(major_locs)
#    1107         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
# -> 1108             tick.update_position(loc)
#    1109             tick.set_label1(label)
#    1110             tick.set_label2(label)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in update_position(self, loc)
#     503         self.tick1line.set_xdata((loc,))
#     504         self.tick2line.set_xdata((loc,))
# --> 505         self.gridline.set_xdata((loc,))
#     506         self.label1.set_x(loc)
#     507         self.label2.set_x(loc)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/lines.py in set_xdata(self, x)
#    1293         self._xorig = x
#    1294         self._invalidx = True
# -> 1295         self.stale = True
#    1296
#    1297     def set_ydata(self, y):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in stale(self, val)
#     222         # draw stack and is not expected to be drawn as part of the normal
#     223         # draw loop (when not saving) so do not propagate this change
# --> 224         if self.get_animated():
#     225             return
#     226
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in get_animated(self)
#     804     def get_animated(self):
#     805         """Return the animated state."""
# --> 806         return self._animated
#     807
#     808     def get_in_layout(self):
#
# KeyboardInterrupt:

# %%
alpha = 0.0005

# %%
gradient_descent(f, f_dash, x, alpha, epsilon)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-9a16b9b809d6> in <module>
# ----> 1 gradient_descent(f, f_dash, x, alpha, epsilon)
#
# <ipython-input-28-4cd051a7ce8a> in gradient_descent(f, f_dash, x, alpha, epsilon)
#      23
#      24
# ---> 25         draw_plot(f, 1, 8, xs, ys)
#      26         if delta_y < epsilon and step_count >= 1000:
#      27             break
#
# <ipython-input-12-61901300084b> in draw_plot(f, x_begin, x_end, xs, ys)
#      14     plt.title("f(x)")
#      15
# ---> 16     plt.show()
#      17
#      18     clear_output(wait=True)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2100                         self.figure.draw(renderer)
#    2101                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
# -> 2102                     bbox_inches = self.figure.get_tightbbox(renderer,
#    2103                             bbox_extra_artists=bbox_artists)
#    2104                     pad = kwargs.pop("pad_inches", None)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2392                 # need this conditional....
#    2393                 try:
# -> 2394                     bbox = ax.get_tightbbox(renderer,
#    2395                             bbox_extra_artists=bbox_extra_artists)
#    2396                 except TypeError:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4321
#    4322         if self.axison:
# -> 4323             bb_xaxis = self.xaxis.get_tightbbox(renderer)
#    4324             if bb_xaxis:
#    4325                 bb.append(bb_xaxis)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1186         ticks_to_draw = self._update_ticks()
#    1187
# -> 1188         self._update_label_position(renderer)
#    1189
#    1190         # go back to just this axis's tick labels
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2019         # get bounding boxes for this axis and any siblings
#    2020         # that have been set by `fig.align_xlabels()`
# -> 2021         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2022
#    2023         x, y = self.label.get_position()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    2003         # if we want to align labels from other axes:
#    2004         for nn, axx in enumerate(grp.get_siblings(self.axes)):
# -> 2005             ticks_to_draw = axx.xaxis._update_ticks()
#    2006             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2007             bboxes.extend(tlb)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1106         self.major.formatter.set_locs(major_locs)
#    1107         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
# -> 1108             tick.update_position(loc)
#    1109             tick.set_label1(label)
#    1110             tick.set_label2(label)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axis.py in update_position(self, loc)
#     507         self.label2.set_x(loc)
#     508         self._loc = loc
# --> 509         self.stale = True
#     510
#     511     def get_view_interval(self):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in stale(self, val)
#     226
#     227         if val and self.stale_callback is not None:
# --> 228             self.stale_callback(self, val)
#     229
#     230     def get_window_extent(self, renderer):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in _stale_axes_callback(self, val)
#      49 def _stale_axes_callback(self, val):
#      50     if self.axes:
# ---> 51         self.axes.stale = val
#      52
#      53
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in stale(self, val)
#     226
#     227         if val and self.stale_callback is not None:
# --> 228             self.stale_callback(self, val)
#     229
#     230     def get_window_extent(self, renderer):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in _stale_figure_callback(self, val)
#      45 def _stale_figure_callback(self, val):
#      46     if self.figure:
# ---> 47         self.figure.stale = val
#      48
#      49
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in stale(self, val)
#     222         # draw stack and is not expected to be drawn as part of the normal
#     223         # draw loop (when not saving) so do not propagate this change
# --> 224         if self.get_animated():
#     225             return
#     226
#
# KeyboardInterrupt:
