# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_pickle('/content/drive/MyDrive/Courses /Старт ИИ/14.Линейная регрессия/newpeng.pkl')
data = data.rename(columns={
    'species': 'вид',
    'island': 'остров',
    'bill_length_mm': 'длина клюва',
    'bill_depth_mm': 'ширина клюва',
    'flipper_length_mm': 'длина плавника',
    'body_mass_g': 'масса тела',
    'sex': 'пол'
})

# %%
X = data[['масса тела']]
y = data['длина плавника']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

# %%
plt.scatter(X_train, y_train)

plt.xlabel('масса тела (мм)');
plt.ylabel('длина плавника (мм)');

plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_, lr.intercept_
# Out:
# (array([0.01518554]), 136.8503444172987)

# %%
plt.scatter(X_train, y_train)


def f_line(x):
  return lr.coef_*x + lr.intercept_

x = [2500, 6000]
y = f_line(x)
plt.plot(x, y)


plt.xlabel('масса тела (мм)')
plt.ylabel('длина плавника (мм)')

plt.show()

# %%
plt.scatter(X_test, y_test)


def f_line(x):
  return lr.coef_*x + lr.intercept_

x = [2500, 6000]
y = f_line(x)
plt.plot(x, y)


plt.xlabel('масса тела (мм)')
plt.ylabel('длина плавника (мм)')

plt.show()

# %%
y_train_predicted = lr.predict(X_train)

y_test_predicted = lr.predict(X_test)

# %%
np.array(y_test)
# Out:
# array([189., 215., 208., 190., 229., 225., 218., 216., 197., 180., 190.,
#        198., 210., 187., 212., 194., 223., 225., 214., 190., 219., 191.,
#        218., 184., 202., 210., 230., 222., 185., 219., 187., 221., 185.,
#        199., 191., 210., 220., 193., 196., 194., 219., 208., 192., 210.,
#        203., 196., 189., 184., 228., 215.])

# %%
np.array(y_test_predicted)
# Out:
# array([185.44406599, 212.39839593, 202.14815779, 201.38888089,
#        224.92646477, 218.85224958, 223.40791098, 208.22237298,
#        199.87032709, 194.55538879, 191.13864274, 203.66671158,
#        202.14815779, 180.8884046 , 202.14815779, 194.17575034,
#        227.20429547, 212.77803438, 210.50020368, 196.83321949,
#        220.37080338, 185.06442754, 212.01875748, 189.62008894,
#        190.75900429, 204.42598848, 223.40791098, 224.16718787,
#        191.51828119, 210.50020368, 188.86081204, 219.61152648,
#        182.4069584 , 204.80562693, 193.03683499, 206.70381918,
#        221.13008028, 181.26804305, 192.65719654, 190.37936584,
#        216.57441888, 200.62960399, 177.851297  , 208.22237298,
#        198.35177329, 198.73141174, 196.83321949, 196.07394259,
#        221.88935718, 212.77803438])

# %%
plt.scatter(X_test[:5], y_test[:5])

plt.scatter(X_test[:5], y_test_predicted[:5])

def f_line(x):
  return lr.coef_*x + lr.intercept_
x_line = np.linspace(2500, 6000, 100)
y_line = f_line(x_line)
plt.plot(x_line, y_line)

plt.xlabel('масса  тела (мм)')
plt.ylabel('длина плавника (мм)')

plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(y_train_predicted, y_train), mean_absolute_error(y_test_predicted, y_test)
# Out:
# (5.59562325661515, 5.588693838064707)

# %%
np.mean(np.abs(y_train_predicted - y_train))
# Out:
# 5.59562325661515

# %%
mean_squared_error(y_train_predicted, y_train), mean_squared_error(y_test_predicted, y_test)
# Out:
# (47.13694237864762, 43.8787364811299)

# %%
np.mean((y_train_predicted - y_train) ** 2)
# Out:
# 47.13694237864762

# %% [markdown]
# linear regression with 2 undependet

# %%
data.head()
# Out:
#    вид  остров  длина клюва  ширина клюва  длина плавника  масса тела  пол
# 0    0       2         39.1          18.7           181.0      3750.0    1
# 1    0       2         39.5          17.4           186.0      3800.0    0
# 2    0       2         40.3          18.0           195.0      3250.0    0
# 4    0       2         36.7          19.3           193.0      3450.0    0
# 5    0       2         39.3          20.6           190.0      3650.0    1

# %%
X = data[['масса тела', 'длина клюва']]
y = data['длина плавника']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

# %%
# %matplotlib inline


fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')

x_points = X_train['масса тела']
y_points = X_train['длина клюва']
z_points = y_train

ax.scatter(x_points, y_points, z_points)

ax.set_xlabel('масса тела');
ax.set_ylabel('длина клюва');
ax.set_zlabel('длина плавника');

plt.show()

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_predicted = lr.predict(X_train)

y_train_predicted
# Out:
# array([186.43761187, 207.16460104, 185.72245375, 199.04956356,
#        190.54173655, 190.48231072, 228.15453296, 220.81123057,
#        204.24494304, 194.64301236, 214.61535962, 204.62348826,
#        181.56460098, 198.38975813, 200.87836708, 186.18606457,
#        191.75144268, 201.305343  , 187.83251748, 210.71760074,
#        233.13784892, 203.51838946, 191.39406378, 202.09377094,
#        192.9245139 , 218.27581552, 198.62013911, 181.20844635,
#        207.34002965, 192.58545246, 204.73949105, 201.37046655,
#        212.66932905, 193.2749708 , 199.15294663, 183.05841618,
#        218.87781972, 206.11323034, 190.03294422, 199.93445257,
#        213.1455596 , 224.70614058, 189.5538648 , 219.03615515,
#        212.53785767, 189.38860738, 231.13931451, 221.86545014,
#        185.20796369, 185.01014449, 198.36289408, 209.84980492,
#        210.9268154 , 195.77375094, 189.67394072, 214.86690692,
#        219.64100822, 198.68486234, 191.24549921, 184.33039701,
#        207.88260803, 215.27678965, 196.46896701, 199.10898939,
#        198.52530264, 187.94974454, 188.93069428, 195.25356315,
#        192.13608595, 178.87654823, 221.62244943, 205.85313644,
#        212.5887369 , 224.50547252, 196.31917818, 180.93573273,
#        220.04234435, 217.46459666, 195.12656523, 186.88412951,
#        198.71904871, 201.19218907, 202.80892906, 186.22839721,
#        195.40620085, 197.96155795, 198.66247175, 179.23555172,
#        192.88503012, 218.37187626, 205.18315982, 203.07756955,
#        190.04149081, 211.50480442, 195.01341131, 223.54161596,
#        222.73894369, 222.73609483, 185.31257102, 192.67011773,
#        215.94106854, 197.30297679, 183.89934796, 191.13804302,
#        204.02148406, 198.24974016, 193.56762647, 218.37187626,
#        198.15083056, 200.92639745, 209.99959375, 223.64337442,
#        211.32530267, 199.30965746, 202.97581109, 211.19952902,
#        206.85932564, 186.37533718, 210.81081262, 184.42360888,
#        214.82457428, 191.19746884, 192.91881617, 206.9159026 ,
#        186.00371396, 221.9220271 , 208.33482339, 198.92256565,
#        203.71905753, 196.30493385, 201.09043061, 212.80649816,
#        191.82633709, 224.24822749, 186.08430611, 191.35580427,
#        193.39952018, 186.50965742, 203.00674827, 188.87411732,
#        217.61153663, 186.73434068, 200.67485015, 204.25756277,
#        202.81177793, 197.73240124, 192.89764985, 195.46847554,
#        193.9307031 , 180.96259678, 195.75950661, 219.03330629,
#        204.69430954, 191.64683535, 209.85550265, 207.58587922,
#        221.15883861, 207.52360453, 189.1496798 , 197.83985743,
#        197.38194434, 192.15847654, 193.79515859, 190.17703532,
#        209.61819967, 195.9361595 , 202.04858944, 188.36247613,
#        195.30444238, 201.59637407, 196.9268801 , 188.04865414,
#        211.93015574, 198.08448274, 192.18411632, 212.49267616,
#        191.64968421, 208.64009879, 194.89455965, 226.9843106 ,
#        182.87891444, 200.88121594, 198.0405255 , 187.51869549,
#        216.34240467, 186.88412951, 193.42191077, 202.26635069,
#        214.67763431, 197.42875044, 189.92263916, 204.2026104 ,
#        212.13367267, 213.1992877 , 206.71523454, 204.02718179,
#        204.33245719, 186.03057801, 183.034401  , 190.66466133,
#        182.27406137, 195.78229753, 206.2219108 , 181.61832907,
#        201.88740514, 183.1870387 , 209.02596633, 215.93252195,
#        194.45373975, 188.2578688 , 191.04483115, 192.4128727 ,
#        194.64016349, 222.02378557, 203.86314863, 220.55113668,
#        200.90523113, 187.14137454, 212.01074788, 201.14823183,
#        209.92062621, 194.70813591, 208.23876266, 208.84076686,
#        200.52221245, 205.41638967, 203.1113556 , 183.1418572 ,
#        196.86907888, 209.96010998, 190.08382345, 191.44331841,
#        182.55124845, 188.3030503 , 212.59158577, 195.8303279 ,
#        219.94628361, 209.64913685, 201.74901177, 199.15701976,
#        200.08424141, 214.47411738, 190.33537075, 191.85035228,
#        215.37854811, 192.75640761, 208.53549146, 221.66763094,
#        213.75611039, 209.4781817 , 208.6698117 , 192.65464914,
#        194.69389159, 218.47078586, 189.99753357, 198.3372543 ,
#        219.38091432, 193.83464236, 188.40765763, 228.21395879,
#        182.78000484, 193.42191077, 202.92778072, 197.2321555 ,
#        195.22954797, 206.50601987, 225.32808684, 201.55404143,
#        185.44119353, 210.81935921, 189.02105729, 186.68915917,
#        226.83452177, 225.26296328, 201.4946156 , 188.87411732,
#        179.18467249, 183.30304149, 208.68812916, 201.55973916,
#        206.80844641, 190.89789118, 185.41432949])

# %%
lr.coef_, lr.intercept_
# Out:
# (array([0.01317162, 0.50879233]), 123.12550546514657)

# %%
def f_plane(x1, x2):
  return lr.coef_[0]*x1 + lr.coef_[1]*x2 + lr.intercept_

# %%
X_train['длина клюва'].min(), X_train['длина клюва'].max()
# Out:
# (34.0, 59.6)

# %%
# %matplotlib inline

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(projection='3d')

x_points = X_train['масса тела']
y_points = X_train['длина клюва']
z_points = y_train


ax.scatter(x_points, y_points, z_points)

x, y = np.meshgrid(range(2800, 6350), range(30, 61));
z = np.array([f_plane(point_x, point_y) for point_x, point_y in zip(x, y)]);
ax.plot_surface(x, y, z, alpha=0.2);

ax.set_xlabel('масса тела');
ax.set_ylabel('длина клюва');
ax.set_zlabel('длина плавника');

plt.show()

# %%
data.head()
# Out:
#    вид  остров  длина клюва  ширина клюва  длина плавника  масса тела  пол
# 0    0       2         39.1          18.7           181.0      3750.0    1
# 1    0       2         39.5          17.4           186.0      3800.0    0
# 2    0       2         40.3          18.0           195.0      3250.0    0
# 4    0       2         36.7          19.3           193.0      3450.0    0
# 5    0       2         39.3          20.6           190.0      3650.0    1

# %%
X = data.drop(columns=['масса тела'])
y = data['масса тела']

# %%
X.head()
# Out:
#    вид  остров  длина клюва  ширина клюва  длина плавника  пол
# 0    0       2         39.1          18.7           181.0    1
# 1    0       2         39.5          17.4           186.0    0
# 2    0       2         40.3          18.0           195.0    0
# 4    0       2         36.7          19.3           193.0    0
# 5    0       2         39.3          20.6           190.0    1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_predicted = lr.predict(X_train)
y_test_predicted = lr.predict(X_test)

# %%
mean_absolute_error(y_train_predicted, y_train), mean_absolute_error(y_test_predicted, y_test)
# Out:
# (264.15146504653904, 271.645876381468)

# %%
mean_squared_error(y_train_predicted, y_train), mean_squared_error(y_test_predicted, y_test)
# Out:
# (104084.57334589418, 117008.7223288536)

# %%
X_train.head()
# Out:
#      вид  остров  длина клюва  ширина клюва  длина плавника  пол
# 211    2       0         50.4          15.3           224.0    1
# 201    2       0         45.2          15.8           215.0    1
# 214    2       0         45.7          13.9           214.0    0
# 150    0       1         36.0          17.1           187.0    0
# 288    1       1         47.0          17.3           185.0    0

# %%
lr.coef_, lr.intercept_
# Out:
# (array([ 270.63789142, -123.58539971,  -21.51112819,  -19.094085  ,
#           30.02857656,  582.10169317]), -1017.6526992697727)

# %%
for i, feature in enumerate(X_train.columns):
  print(feature, ' '*(19-len(feature)), '|  ', 'k_'+str(i+1), '  |  ', lr.coef_[i])
# Out:
# вид                  |   k_1   |   270.63789142329233
# остров               |   k_2   |   -123.58539971022468
# длина клюва          |   k_3   |   -21.511128190835237
# ширина клюва         |   k_4   |   -19.094084996677893
# длина плавника       |   k_5   |   30.028576560023282
# пол                  |   k_6   |   582.1016931741887

# %%
X_train['длина плавника'].min(), X_train['длина плавника'].max()
# Out:
# (172.0, 231.0)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor(n_neighbors=5)

# %%
knn.fit(X_train, y_train)
y_train_predicted_knn = knn.predict(X_train)
y_test_predicted_knn = knn.predict(X_test)

# %%
y_train_predicted_lr = lr.predict(X_train)
y_test_predicted_lr = lr.predict(X_test)

# %%
mean_absolute_error(y_train_predicted_knn, y_train), mean_squared_error(y_train_predicted_knn, y_train)
# Out:
# (228.0565371024735, 82331.27208480565)

# %%
mean_absolute_error(y_test_predicted_knn, y_test), mean_squared_error(y_test_predicted_knn, y_test)
# Out:
# (236.6, 96850.0)

# %%
mean_absolute_error(y_train_predicted_lr, y_train), mean_squared_error(y_train_predicted_lr, y_train)
# Out:
# (264.15146504653904, 104084.57334589418)

# %%
mean_absolute_error(y_test_predicted_lr, y_test), mean_squared_error(y_test_predicted_lr, y_test)
# Out:
# (271.645876381468, 117008.7223288536)
